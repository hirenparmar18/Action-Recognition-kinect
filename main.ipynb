# %% [markdown]
# ## Import required Libraries

# %%
import scipy.io
import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML
import pandas as pd

import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %% [markdown]
# # Define action names for each classes

# %%
action_names = ['Swipe left','Swipe right','Wave','Clap','Throw','Arm cross','Basketball shoot',
                'Draw X','Draw circle (clockwise)','Draw circle (counter clockwise)','Draw triangle',
                'Bowling','Boxing','Baseball swing','Tennis swing','Arm curl','Tennis serve','Push',
                'Knock','Catch','Pickup and throw','Jog','Walk','Sit to stand','Stand to sit','Lunge','Squat']

# %% [markdown]
# # Create editable path string

# %%
# Create path for all 
path = './{0}/a{1}_s{2}_t{3}_{4}.mat'

# %% [markdown]
#  #  Get one sample from database to visualise

# %%
# Define actionID, subjectID and sampleID
aID = 2
sID = 1
tID = 1

# Create paths for Depth, Skeleton and Inertial Sensor files
Dpath = path.format('depth',aID,sID,tID,'depth')
Spath = path.format('skeleton',aID,sID,tID,'skeleton')
Ipath = path.format('inertial',aID,sID,tID,'inertial')

# %% [markdown]
# ## 1. Depth

# %%
# read .MAT file for Dpath
matD = scipy.io.loadmat(Dpath)

# Obtain d_depth from matD dictionary.
D = matD['d_depth']

# Get number of frames based on 3rd dimension of matrix
numFrames = D.shape[-1]
print('Total number of frames: ', numFrames)
# Out:
# Total number of frames:  61

# %% [markdown]
# ### Visualise sequence

# %%
fig = plt.figure()

hw=0.3
index = 0;

# Calculate number of rows
nrows = int(np.floor(numFrames/8))
for j in range(0,nrows):
    for i in range(0,8):
        ax = fig.add_axes([(i+1)*hw, (j+1)*hw, hw, hw],
                           xticklabels=[])

        ax.imshow(D[:,:,index])
        index +=1

# %% [markdown]
# ### Write function to create feature matrix from all Depth frames

# %%
def average_frame(D):
    D1 = D.max(axis=2)
    D2 = D.min(axis=2)
    Dmid = D1+D2
    # Option 2 is averaging all values which is not so effective.
    #     Dmid = np.mean(D,axis=2)
    # Normalise between 0 - 1
    Dmid = Dmid/np.max(Dmid)
    return Dmid

# %% [markdown]
# ### Create feature matrix and show

# %%
# Call feature extractor function
Dmid = average_frame(D)
# %matplotlib inline
plt.imshow(Dmid)

# %% [markdown]
# ### Visualise extracted features from each class

# %%
fig = plt.figure(figsize=(20,12))
# imstack = np.empty((200,200))
for aID  in range(1,28):
    Dpath = path.format('depth',aID,sID,tID,'depth')
    
    # read .MAT file for Dpath
    matD = scipy.io.loadmat(Dpath)

    # Obtain d_depth from matD dictionary.
    D = matD['d_depth']
    
    Dmid = average_frame(D)
    
    Dcrop = Dmid[40:,50:250]
 
    # imstack = np.dstack((imstack,Dcrop))

    plt.subplot(4,7, aID)
    plt.imshow(Dcrop)
    plt.title(action_names[aID-1],color = 'r')

# %% [markdown]
# ### Extract featues from all Depth files from dataset

# %%
# %%time
fig = plt.figure(figsize=(15,15))
imstack = np.empty((200,200))
Dtarget = []
for aID  in range(1,28):
    for sID in range(1,9):
        for tID in range(1,5):
            Dpath = path.format('depth',aID,sID,tID,'depth')

            # read .MAT file for Dpath
            matD = scipy.io.loadmat(Dpath)

            # Obtain d_depth from matD dictionary.
            D = matD['d_depth']

            Dmid = average_frame(D)

            Dcrop = Dmid[40:,50:250]

            imstack = np.dstack((imstack,Dcrop))

            Dtarget.append(aID-1)
            
Dtarget = np.array(Dtarget)
# Out:
# Wall time: 1min 45s

# %%
print('The shape of input Depth data:',imstack.shape)
# Out:
# The shape of input Depth data: (200, 200, 865)

# %% [markdown]
# ### Reshape Depth data so that no of sample should be X values

# %%
imstack_norm=np.rollaxis(imstack,2,0)
imstack_norm.shape
# Out:
# (865, 200, 200)

# %%
# Remove first entry which is empty
imstack_norm = imstack_norm[1:,:,:]
imstack_norm.shape
# Out:
# (864, 200, 200)

# %% [markdown]
# Total number of freaures 864 (27 actions x 8 subjects x 4 samples)

# %% [markdown]
# ## Skeleton Data

# %%
# read .MAT file for Skeleton
matS = scipy.io.loadmat(Spath)

# %%
# GEt skeleton data from dictionary
S = matS['d_skel']
# Get number of frames based on 3rd dimension of matrix
numFrames =S.shape[-1]

# %% [markdown]
# ## Write some functions to display skeleton in 2D and 3D

# %%
def plot_im_skeleton(skeleton,ax):
    ''' This function defines the bone list and plot the skeleton from given cordinates'''

#     bone_list = [[0,1],[1,20],[20, 2], [2, 3], [2, 4], [4, 5], [5, 6], [6,7],[2, 8], [8,9], [9,10], [10, 11], 
#             [0,12],[12,13],[13, 14], [14, 15],[0,16],[16, 17], [17,18], [18, 19], [7, 21],[7,22],[11,23],[11,24]]#, [11, 22], [12, 13], ,[22,23],[23,24],[24,25]]
    bone_list = [[0,1],[1,2], [2, 3], [1, 4], [4, 5], [5, 6], [6,7],[1, 8], [8,9], [9,10], [10, 11], 
            [3,12],[12,13],[13, 14], [14, 15],[3,16],[16, 17], [17,18], [18, 19]]#, [11, 22], [12, 13], ,[22,23],[23,24],[24,25]]

    x = skeleton[:, 0]
    y = skeleton[:, 1]
    sc = ax.scatter(x, y, s=40,)
    for bone in bone_list:
        ax.plot([x[bone[0]], x[bone[1]]], [y[bone[0]], y[bone[1]]], 'r')

# %%
def plot_3D_skeleton(skeleton,ax):
    ''' This function defines the bone list and plot the skeleton from given cordinates'''

#     bone_list = [[0,1],[1,2], [2, 3], [2, 4], [4, 5], [5, 6], [6,7],[2, 8], [8,9], [9,10], [10, 11], 
#             [0,12],[12,13],[13, 14], [14, 15],[0,16],[16, 17], [17,18], [18, 19], [7, 21],[7,22],[11,23],[11,24]]#, [11, 22], [12, 13], ,[22,23],[23,24],[24,25]]
    bone_list = [[0,1],[1,2], [2, 3], [1, 4], [4, 5], [5, 6], [6,7],[1, 8], [8,9], [9,10], [10, 11], 
            [3,12],[12,13],[13, 14], [14, 15],[3,16],[16, 17], [17,18], [18, 19]]#, [11, 22], [12, 13], ,[22,23],[23,24],[24,25]]

    x = skeleton[:, 0]
    z = skeleton[:, 1]
    y = skeleton[:, 2]
    sc = ax.scatter(x, y, z, s=20)
    for bone in bone_list:
        ax.plot([x[bone[0]], x[bone[1]]], [y[bone[0]], y[bone[1]]], [z[bone[0]], z[bone[1]]], 'b')

# %% [markdown]
# ## Write function to create feature image

# %%
def interp_vals(yin,numFrames):
    ''' This function interpolate Values of sensor according to number of frames'''
    xin = np.linspace(0, numFrames, len(yin))
    xnew = np.arange(0, numFrames)
    ynew = np.interp(xnew, xin, yin)
    return ynew

# %%
def norm_vals(x):
    '''Function to normalise any values between 0 to 1'''
    x = x-np.min(x)
    x = x/np.max(x)
    return x

# %%
def extract_features(S,flength,spoints):
    ''' This function takes x,y and z cordinate of specified skeleton joint and interpolate all values to given flength, 
    Finally normalise all values between 0-1 and return it as feature matrix'''
    feature_matrix = np.zeros((len(spoints)*3,flength))
    for i in range(len(spoints)):
        # Get X values for all frames
        sx = S[spoints[i],0,:]

        # Get Y values for all frames
        sy = S[spoints[i],1,:]

        # Get Z values for all frames
        sz = S[spoints[i],2,:]

        # Interpolate values
        sxi = interp_vals(sx,flength)
        syi = interp_vals(sy,flength)
        szi = interp_vals(sz,flength)

        # Normalise values
        sxi = norm_vals(sxi)
        syi = norm_vals(syi)
        szi = norm_vals(szi)
        
        # Store values into feature matrix
        feature_matrix[i*3,:] = sxi
        feature_matrix[i*3+1,:] = syi
        feature_matrix[i*3+2,:] = szi    
        
    return feature_matrix

# %% [markdown]
# ### Plot skeleton of first frame

# %%
ax = plt.axes(projection='3d')
ax.scatter([-0.5, 0.5],[1,4],[-0.5,0.5],)
plot_3D_skeleton(S[:,:,0],ax)

# %% [markdown]
# ## Visualise sequence of all frames

# %%
# Skeleton Values
# %matplotlib notebook
#calling it a second time may prevent some graphics errors
# %matplotlib notebook
# %matplotlib notebook
for i in range(numFrames):
    skeleton = S[:,:,i] 
    ax = plt.axes(projection='3d')
    ax.scatter([-0.5, 0.5],[1,4],[-0.5,0.5],)
    plot_3D_skeleton(skeleton,ax)
    ax.mouse_init()
    plt.show()
    ax.set_title(['Frame: ',i])
    plt.pause(0.05)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ### Plot 2D skeleton

# %%
# %matplotlib inline
fig, ax = plt.subplots(nrows=1,ncols=1,figsize=(3,6))
plot_im_skeleton(S[:,:,0],ax)
for i in range(20):
    plt.text(S[i,0,0],S[i,1,0],i,fontsize = 16)

# %% [markdown]
# # Extract features of one sample and show

# %%
# %matplotlib inline
# Define feature length
flength = 60
# Skeleton points to be considered for features
spoints = [1,11,7,8,4,15,19,3]

# Call function to extract feature matrix
fm = extract_features(S,flength,spoints)

# show image
plt.imshow(fm)

# %% [markdown]
# ### Show extracted sample of each class

# %%
# %matplotlib inline
# Define feature length
flength = 60
# Skeleton points to be considered for features
spoints = [1,11,7,8,4,15,19,3]

fig = plt.figure(figsize=(20,12))
# imstack = np.empty((200,200))
for aID  in range(1,28):
    Spath = path.format('skeleton',aID,sID,tID,'skeleton')
    
    # read .MAT file for Dpath
    matS = scipy.io.loadmat(Spath)

    # Obtain d_depth from matD dictionary.
    S = matS['d_skel']
    
    fm = extract_features(S,flength,spoints)
    
    plt.subplot(6,5, aID)
    plt.imshow(fm)
    plt.title(action_names[aID-1],color='r')

# %% [markdown]
# ### Extract features for all dataset sample of skeleton

# %%
# %%time
# Define feature length
flength = 60
# Skeleton points to be considered for features
spoints = [1,11,7,8,4,15,19,3]

Sstack = np.zeros((len(spoints)*3,flength))
Starget = []
for aID  in range(1,28):
    for sID in range(1,9):
        for tID in range(1,5):
            Spath = path.format('skeleton',aID,sID,tID,'skeleton')
    
            # read .MAT file for Dpath
            matS = scipy.io.loadmat(Spath)

            # Obtain d_depth from matD dictionary.
            S = matS['d_skel']

            fm = extract_features(S,flength,spoints)
            
            Sstack = np.dstack((Sstack,fm))

            Starget.append(aID-1)
            
Starget = np.array(Starget)
# Out:
# Wall time: 6.42 s

# %% [markdown]
# ### Reshape Skeleton data so that no of sample should be X values

# %%
Sstack_norm=np.rollaxis(Sstack,2,0)
Sstack_norm.shape
# Out:
# (865, 24, 60)

# %% [markdown]
# ### Delete first empty sample

# %%
Sstack_norm = Sstack_norm[1:,:,:]

# %% [markdown]
# # Inertial Data

# %%
# Inertial
mat_inn = scipy.io.loadmat(Ipath)

# %%
# Get sensor value
d_iner = mat_inn['d_iner']

# %% [markdown]
#  ### Write function to interpolate matrix

# %%
def interpolate_cols(d_iner,interpval=60):
    # Intialise empty matrix
    imat = np.zeros((interpval,d_iner.shape[1]))
    for i in range(d_iner.shape[1]):
        val = d_iner[:,i]
        ival = interp_vals(val,interpval)
        
        # normalise values between 0-1
        ival = norm_vals(ival)
        
        # Store values back to matrix
        imat[:,i] = ival
    return imat

# %%
imat = interpolate_cols(d_iner,60)
imat.shape
# Out:
# (60, 6)

# %% [markdown]
# ## Plot one sample

# %%
# %matplotlib inline
fig, ax = plt.subplots(nrows=2,ncols=1,figsize=(10,6))
ax[0].plot(imat[:,0:3])
ax[0].legend(labels=['X_acc','Y_acc','Z_acc'],loc='upper right')
ax[0].grid(True)
ax[1].plot(imat[:,3:])
ax[1].legend(labels=['X_avl','Y_avl','Z_avl'],loc='upper right')
ax[1].grid(True)
# plt.legend()

# %% [markdown]
# # Extract features from all Sensor data

# %%
# %matplotlib inline
# Define feature length
flength = 60

fig = plt.figure(figsize=(15,13))
# imstack = np.empty((200,200))
for aID  in range(1,28):
    Ipath = path.format('inertial',aID,sID,tID,'inertial')

    # Inertial
    mat_inn = scipy.io.loadmat(Ipath)

    # Get sensor value
    d_iner = mat_inn['d_iner']

    # interpolate and normalise all columns
    fi = interpolate_cols(d_iner,flength)
    
    plt.subplot(3,9, aID)
    plt.imshow(fi)
    plt.title(action_names[aID-1],color='r')

# %%
# %%time
# Define feature length
flength = 60

Istack = np.zeros((flength,6))
Itarget = []
for aID  in range(1,28):
    for sID in range(1,9):
        for tID in range(1,5):
            Ipath = path.format('inertial',aID,sID,tID,'inertial')
            
            # Inertial
            mat_inn = scipy.io.loadmat(Ipath)

            # Get sensor value
            d_iner = mat_inn['d_iner']

            # interpolate and normalise all columns
            fi = interpolate_cols(d_iner,flength)
            
            Istack = np.dstack((Istack,fi))

            Itarget.append(aID-1)
            
# Delete first entry
Istack = Istack[:,:,1:]
Itarget = np.array(Itarget)
# Out:
# Wall time: 2.02 s

# %%
Istack.shape
# Out:
# (60, 6, 864)

# %% [markdown]
# ### Reshape matrix as per Deep learning standard

# %%
Istack_norm=np.rollaxis(Istack,2,0)
Istack_norm.shape
# Out:
# (864, 60, 6)

# %%
Sstack_norm.shape
# Out:
# (864, 24, 60)

# %% [markdown]
# # -------------- Modelling ----------------------------

# %% [markdown]
# ### Write function to calculate accuracy, recall and precision

# %%
def cal_results(Dy_test,Fy_pred):
    CM = confusion_matrix(Dy_test,Fy_pred)
    accuracy = np.sum(np.diag(CM))/np.sum(CM)
    recall = np.mean(np.diag(CM) / np.sum(CM, axis = 1))
    precision = np.mean(np.diag(CM) / np.sum(CM, axis = 0))
    return accuracy,recall,precision

# %%
# Define test size
Tsize= 0.66
DX_train, DX_test, Dy_train, Dy_test = train_test_split(imstack_norm,Dtarget, test_size=Tsize,
                                                    random_state=42,stratify=Dtarget)
SX_train, SX_test, Sy_train, Sy_test = train_test_split(Sstack_norm,Starget, test_size=Tsize,
                                                    random_state=42,stratify=Starget)
IX_train, IX_test, Iy_train, Iy_test = train_test_split(Sstack_norm,Itarget, test_size=Tsize,
                                                    random_state=42,stratify=Itarget)

# %%
def evaluate_model_1(X_train,X_test,y_train,y_test):
    '''This function train model 1 based on X_train and y_train'''
    model = keras.Sequential([
        keras.layers.Flatten(input_shape=X_train.shape[1:]),
        keras.layers.Dense(128,activation=tf.nn.relu),
        keras.layers.Dense(128,activation=tf.nn.relu),
        keras.layers.Dense(27,activation=tf.nn.softmax)
    ])
    model.compile(optimizer = tf.train.AdamOptimizer(),
                 loss = 'sparse_categorical_crossentropy',
                 metrics = ['accuracy'])
    # model.fit(imstack_norm,np.array(target),epochs=10)
    model.fit(X_train,y_train,epochs=20)
    return model

# %%
def evaluate_model_2(X_train,X_test,y_train,y_test):
    '''This function train model 1 based on X_train and y_train'''
    model = keras.Sequential([
        keras.layers.Flatten(input_shape=X_train.shape[1:]),
        keras.layers.Dense(128,activation=tf.nn.conv2d),
        keras.layers.Dense(128,activation=tf.nn.relu),
        keras.layers.Dense(27,activation=tf.nn.max_pool)
    ])
    model.compile(optimizer = tf.train.AdamOptimizer(),
                 loss = 'sparse_categorical_crossentropy',
                 metrics = ['accuracy'])
    # model.fit(imstack_norm,np.array(target),epochs=10)
    model.fit(X_train,y_train,epochs=20)
    return model

# %% [markdown]
# ## Calculate baseline

# %%
y_pred = np.ones(len(Dtarget))
CM = confusion_matrix(Dtarget,y_pred)
accuracyb = np.sum(np.diag(CM))/np.sum(CM)
recallb = np.mean(np.diag(CM) / np.sum(CM, axis = 1))
precisionb = np.mean(np.diag(CM) / np.sum(CM, axis = 0))
print('Baseline Accuracy',accuracyb)
print('Baseline Recall',recallb)
print('Baseline Precision',precisionb)
# Out:
# Baseline Accuracy 0.037037037037037035
# Baseline Recall 0.037037037037037035
# Baseline Precision nan
# C:\Users\hiren\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in true_divide
#   """

# %%
Dmodel= evaluate_model_1(DX_train,DX_test,Dy_train,Dy_test)
Smodel = evaluate_model_1(SX_train,SX_test,Sy_train,Sy_test)
Imodel = evaluate_model_1(IX_train,IX_test,Iy_train,Iy_test)
# Out:
# WARNING:tensorflow:From C:\Users\hiren\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Epoch 1/20
# 293/293 [==============================] - 1s 2ms/sample - loss: 5.1962 - acc: 0.0614
# Epoch 2/20
# 293/293 [==============================] - 0s 2ms/sample - loss: 3.3331 - acc: 0.1433
# Epoch 3/20
# 293/293 [==============================] - 0s 2ms/sample - loss: 2.7701 - acc: 0.1945
# Epoch 4/20
# 293/293 [==============================] - 0s 2ms/sample - loss: 2.2554 - acc: 0.3038
# Epoch 5/20
# 293/293 [==============================] - 0s 1ms/sample - loss: 1.9012 - acc: 0.4403
# Epoch 6/20
# 293/293 [==============================] - 0s 2ms/sample - loss: 1.8267 - acc: 0.4846
# Epoch 7/20
# 293/293 [==============================] - 0s 2ms/sample - loss: 1.5248 - acc: 0.5324
# Epoch 8/20
# 293/293 [==============================] - 0s 2ms/sample - loss: 1.3730 - acc: 0.5392
# Epoch 9/20
# 293/293 [==============================] - 0s 1ms/sample - loss: 1.1794 - acc: 0.6382
# Epoch 10/20
# 293/293 [==============================] - 0s 1ms/sample - loss: 1.1978 - acc: 0.6280
# Epoch 11/20
# 293/293 [==============================] - 0s 1ms/sample - loss: 0.9678 - acc: 0.7031
# Epoch 12/20
# 293/293 [==============================] - 0s 1ms/sample - loss: 0.7817 - acc: 0.7679
# Epoch 13/20
# 293/293 [==============================] - 0s 1ms/sample - loss: 0.6610 - acc: 0.7850
# Epoch 14/20
# 293/293 [==============================] - 0s 1ms/sample - loss: 0.6711 - acc: 0.8020
# Epoch 15/20
# 293/293 [==============================] - 0s 2ms/sample - loss: 0.5122 - acc: 0.8874
# Epoch 16/20
# 293/293 [==============================] - 0s 2ms/sample - loss: 0.4404 - acc: 0.8908
# Epoch 17/20
# 293/293 [==============================] - 0s 2ms/sample - loss: 0.4269 - acc: 0.8874
# Epoch 18/20
# 293/293 [==============================] - 0s 2ms/sample - loss: 0.3354 - acc: 0.9249
# Epoch 19/20
# 293/293 [==============================] - 0s 2ms/sample - loss: 0.3164 - acc: 0.9352
# Epoch 20/20
# 293/293 [==============================] - 0s 2ms/sample - loss: 0.3313 - acc: 0.9113
# Epoch 1/20
# 293/293 [==============================] - 0s 548us/sample - loss: 3.3034 - acc: 0.0990
# Epoch 2/20
# 293/293 [==============================] - 0s 109us/sample - loss: 2.7721 - acc: 0.2696
# Epoch 3/20
# 293/293 [==============================] - 0s 109us/sample - loss: 2.3498 - acc: 0.3891
# Epoch 4/20
# 293/293 [==============================] - 0s 112us/sample - loss: 1.8744 - acc: 0.5666
# Epoch 5/20
# 293/293 [==============================] - 0s 109us/sample - loss: 1.5619 - acc: 0.5836
# Epoch 6/20
# 293/293 [==============================] - 0s 119us/sample - loss: 1.2261 - acc: 0.7235
# Epoch 7/20
# 293/293 [==============================] - 0s 116us/sample - loss: 1.0003 - acc: 0.7850
# Epoch 8/20
# 293/293 [==============================] - 0s 116us/sample - loss: 0.8436 - acc: 0.8123
# Epoch 9/20
# 293/293 [==============================] - 0s 112us/sample - loss: 0.6114 - acc: 0.9181
# Epoch 10/20
# 293/293 [==============================] - 0s 112us/sample - loss: 0.5293 - acc: 0.9078
# Epoch 11/20
# 293/293 [==============================] - 0s 123us/sample - loss: 0.4307 - acc: 0.9352
# Epoch 12/20
# 293/293 [==============================] - 0s 119us/sample - loss: 0.3681 - acc: 0.9625
# Epoch 13/20
# 293/293 [==============================] - 0s 116us/sample - loss: 0.2949 - acc: 0.9898
# Epoch 14/20
# 293/293 [==============================] - 0s 116us/sample - loss: 0.2592 - acc: 0.9863
# Epoch 15/20
# 293/293 [==============================] - 0s 116us/sample - loss: 0.2444 - acc: 0.9488
# Epoch 16/20
# 293/293 [==============================] - 0s 113us/sample - loss: 0.2064 - acc: 0.9863
# Epoch 17/20
# 293/293 [==============================] - 0s 112us/sample - loss: 0.1485 - acc: 0.9966
# Epoch 18/20
# 293/293 [==============================] - 0s 109us/sample - loss: 0.1435 - acc: 0.9898
# Epoch 19/20
# 293/293 [==============================] - 0s 116us/sample - loss: 0.1161 - acc: 0.9932
# Epoch 20/20
# 293/293 [==============================] - 0s 108us/sample - loss: 0.1312 - acc: 0.9863
# Epoch 1/20
# 293/293 [==============================] - 0s 556us/sample - loss: 3.3010 - acc: 0.1092
# Epoch 2/20
# 293/293 [==============================] - 0s 113us/sample - loss: 2.9199 - acc: 0.1775
# Epoch 3/20
# 293/293 [==============================] - 0s 110us/sample - loss: 2.3768 - acc: 0.4403
# Epoch 4/20
# 293/293 [==============================] - 0s 109us/sample - loss: 1.8586 - acc: 0.5563
# Epoch 5/20
# 293/293 [==============================] - 0s 112us/sample - loss: 1.4863 - acc: 0.6143
# Epoch 6/20
# 293/293 [==============================] - 0s 116us/sample - loss: 1.1533 - acc: 0.7201
# Epoch 7/20
# 293/293 [==============================] - 0s 112us/sample - loss: 0.9269 - acc: 0.7543
# Epoch 8/20
# 293/293 [==============================] - 0s 116us/sample - loss: 0.8199 - acc: 0.8123
# Epoch 9/20
# 293/293 [==============================] - 0s 116us/sample - loss: 0.6224 - acc: 0.8771
# Epoch 10/20
# 293/293 [==============================] - 0s 114us/sample - loss: 0.5220 - acc: 0.8976
# Epoch 11/20
# 293/293 [==============================] - 0s 116us/sample - loss: 0.4315 - acc: 0.9283
# Epoch 12/20
# 293/293 [==============================] - 0s 112us/sample - loss: 0.4045 - acc: 0.9010
# Epoch 13/20
# 293/293 [==============================] - 0s 116us/sample - loss: 0.2735 - acc: 0.9522
# Epoch 14/20
# 293/293 [==============================] - 0s 116us/sample - loss: 0.2374 - acc: 0.9829
# Epoch 15/20
# 293/293 [==============================] - 0s 119us/sample - loss: 0.1897 - acc: 0.9898
# Epoch 16/20
# 293/293 [==============================] - 0s 114us/sample - loss: 0.1557 - acc: 0.9932
# Epoch 17/20
# 293/293 [==============================] - 0s 112us/sample - loss: 0.1352 - acc: 0.9898
# Epoch 18/20
# 293/293 [==============================] - 0s 106us/sample - loss: 0.1171 - acc: 0.9966
# Epoch 19/20
# 293/293 [==============================] - 0s 106us/sample - loss: 0.0948 - acc: 1.0000
# Epoch 20/20
# 293/293 [==============================] - 0s 110us/sample - loss: 0.0927 - acc: 0.9966

# %%
def test_model(y_test,ypred):
    # Find position of maximum value to get predicted output
    y_pred = [np.argmax(i) for i in ypred]
    CM = confusion_matrix(y_test,y_pred)
    accuracy = np.sum(np.diag(CM))/np.sum(CM)
    recall = np.mean(np.diag(CM) / np.sum(CM, axis = 1))
    precision = np.mean(np.diag(CM) / np.sum(CM, axis = 0))
    return accuracy,recall,precision,CM

# %%
# Evaluate all three models
Dypred = Dmodel.predict(DX_test)
Sypred = Smodel.predict(SX_test)
Iypred = Imodel.predict(IX_test)
Fypred = (Dypred+Sypred+Iypred)/3

# %%
Dacc,Drec,Dpre,DCM = test_model(Dy_test,Dypred)
Sacc,Srec,Spre,SCM = test_model(Sy_test,Sypred)
Iacc,Irec,Ipre,ICM = test_model(Iy_test,Iypred)
Facc,Frec,Fpre,FCM = test_model(Dy_test,Fypred)

# %%
print(Dacc,Sacc,Iacc,Facc)
# Out:
# 0.5796847635726795 0.7758318739054291 0.8073555166374781 0.8476357267950964

# %%
DCMdf = pd.DataFrame(DCM,columns=action_names,index=action_names)
plt.figure(figsize = (20,15))
sns.heatmap(DCMdf)

# %%
SCMdf = pd.DataFrame(SCM,columns=action_names,index=action_names)
plt.figure(figsize = (20,15))
sns.heatmap(SCMdf)

# %%
ICMdf = pd.DataFrame(ICM,columns=action_names,index=action_names)
plt.figure(figsize = (20,15))
sns.heatmap(ICMdf)

# %%
FCMdf = pd.DataFrame(FCM,columns=action_names,index=action_names)
plt.figure(figsize = (20,15))
sns.heatmap(FCMdf)

# %%
print(Dacc,Drec,Dpre,Sacc,Srec,Spre,Iacc,Irec,Ipre,Facc,Frec,Fpre)
# Out:
# 0.5796847635726795 0.5804072470739138 0.6993453635095302 0.7758318739054291 0.7769761103094437 0.8085816035902875 0.8073555166374781 0.807679974346641 0.823503730568948 0.8476357267950964 0.8483245149911817 0.8581006478935669

# %%
# %% time
accmat = np.zeros((4,4))
recmat = np.zeros((4,4))
premat = np.zeros((4,4))

index = 0
for Tsize in np.arange(0.2,0.8,0.2):

    DX_train, DX_test, Dy_train, Dy_test = train_test_split(imstack_norm,Dtarget, test_size=Tsize,
                                                        random_state=42,stratify=Dtarget)
    SX_train, SX_test, Sy_train, Sy_test = train_test_split(Sstack_norm,Starget, test_size=Tsize,
                                                        random_state=42,stratify=Starget)
    IX_train, IX_test, Iy_train, Iy_test = train_test_split(Sstack_norm,Itarget, test_size=Tsize,
                                                        random_state=42,stratify=Itarget)

    # Train models
    Dmodel= evaluate_model_1(DX_train,DX_test,Dy_train,Dy_test)
    Smodel = evaluate_model_1(SX_train,SX_test,Sy_train,Sy_test)
    Imodel = evaluate_model_1(IX_train,IX_test,Iy_train,Iy_test)

    # Evaluate all three models
    Dypred = Dmodel.predict(DX_test)
    Sypred = Smodel.predict(SX_test)
    Iypred = Imodel.predict(IX_test)

    # Create fusion result
    Fypred = (Dypred+Sypred+Iypred)/3

    Dacc,Drec,Dpre,DCM = test_model(Dy_test,Dypred)
    Sacc,Srec,Spre,SCM = test_model(Sy_test,Sypred)
    Iacc,Irec,Ipre,ICM = test_model(Iy_test,Iypred)
    Facc,Frec,Fpre,FCM = test_model(Dy_test,Fypred)
    
    accmat[index,:] = [Dacc,Sacc,Iacc,Facc]
    recmat[index,:] = [Drec,Srec,Irec,Frec]
    premat[index,:] = [Dpre,Spre,Ipre,Fpre]
    index+=1
# Out:
# Epoch 1/20
# 691/691 [==============================] - 1s 2ms/sample - loss: 3.7778 - acc: 0.0868
# Epoch 2/20
# 691/691 [==============================] - 1s 2ms/sample - loss: 2.6226 - acc: 0.2822
# Epoch 3/20
# 691/691 [==============================] - 1s 2ms/sample - loss: 2.0457 - acc: 0.3821
# Epoch 4/20
# 691/691 [==============================] - 1s 2ms/sample - loss: 1.6003 - acc: 0.4993
# Epoch 5/20
# 691/691 [==============================] - 1s 1ms/sample - loss: 1.2971 - acc: 0.5861
# Epoch 6/20
# 691/691 [==============================] - 1s 1ms/sample - loss: 1.0706 - acc: 0.6860
# Epoch 7/20
# 691/691 [==============================] - 1s 1ms/sample - loss: 0.8778 - acc: 0.7482
# Epoch 8/20
# 691/691 [==============================] - 1s 1ms/sample - loss: 0.6954 - acc: 0.7916
# Epoch 9/20
# 691/691 [==============================] - 1s 1ms/sample - loss: 0.6001 - acc: 0.8148
# Epoch 10/20
# 691/691 [==============================] - 1s 2ms/sample - loss: 0.5520 - acc: 0.8509
# Epoch 11/20
# 691/691 [==============================] - 1s 2ms/sample - loss: 0.4815 - acc: 0.8582
# Epoch 12/20
# 691/691 [==============================] - 1s 1ms/sample - loss: 0.3726 - acc: 0.8871
# Epoch 13/20
# 691/691 [==============================] - 1s 2ms/sample - loss: 0.3223 - acc: 0.9291
# Epoch 14/20
# 691/691 [==============================] - 1s 2ms/sample - loss: 0.3000 - acc: 0.9247
# Epoch 15/20
# 691/691 [==============================] - 1s 1ms/sample - loss: 0.2345 - acc: 0.9436
# Epoch 16/20
# 691/691 [==============================] - 1s 1ms/sample - loss: 0.1685 - acc: 0.9740
# Epoch 17/20
# 691/691 [==============================] - 1s 1ms/sample - loss: 0.1504 - acc: 0.9768
# Epoch 18/20
# 691/691 [==============================] - 1s 1ms/sample - loss: 0.1326 - acc: 0.9870
# Epoch 19/20
# 691/691 [==============================] - 1s 1ms/sample - loss: 0.1065 - acc: 0.9870
# Epoch 20/20
# 691/691 [==============================] - 1s 1ms/sample - loss: 0.0829 - acc: 0.9913
# Epoch 1/20
# 691/691 [==============================] - 0s 440us/sample - loss: 3.0091 - acc: 0.1447
# Epoch 2/20
# 691/691 [==============================] - 0s 123us/sample - loss: 2.0287 - acc: 0.4703
# Epoch 3/20
# 691/691 [==============================] - 0s 120us/sample - loss: 1.3228 - acc: 0.6411
# Epoch 4/20
# 691/691 [==============================] - 0s 121us/sample - loss: 0.8789 - acc: 0.7902
# Epoch 5/20
# 691/691 [==============================] - 0s 121us/sample - loss: 0.6363 - acc: 0.8394
# Epoch 6/20
# 691/691 [==============================] - 0s 124us/sample - loss: 0.4643 - acc: 0.9074
# Epoch 7/20
# 691/691 [==============================] - 0s 122us/sample - loss: 0.3655 - acc: 0.9334
# Epoch 8/20
# 691/691 [==============================] - 0s 121us/sample - loss: 0.2923 - acc: 0.9421
# Epoch 9/20
# 691/691 [==============================] - 0s 121us/sample - loss: 0.2199 - acc: 0.9682
# Epoch 10/20
# 691/691 [==============================] - 0s 121us/sample - loss: 0.1707 - acc: 0.9812
# Epoch 11/20
# 691/691 [==============================] - 0s 123us/sample - loss: 0.1372 - acc: 0.9826
# Epoch 12/20
# 691/691 [==============================] - 0s 124us/sample - loss: 0.1082 - acc: 0.9913
# Epoch 13/20
# 691/691 [==============================] - 0s 118us/sample - loss: 0.0979 - acc: 0.9928
# Epoch 14/20
# 691/691 [==============================] - 0s 127us/sample - loss: 0.0781 - acc: 0.9957
# Epoch 15/20
# 691/691 [==============================] - 0s 121us/sample - loss: 0.0588 - acc: 0.9957
# Epoch 16/20
# 691/691 [==============================] - 0s 118us/sample - loss: 0.0502 - acc: 1.0000
# Epoch 17/20
# 691/691 [==============================] - 0s 124us/sample - loss: 0.0396 - acc: 1.0000
# Epoch 18/20
# 691/691 [==============================] - 0s 121us/sample - loss: 0.0391 - acc: 1.0000
# Epoch 19/20
# 691/691 [==============================] - 0s 121us/sample - loss: 0.0303 - acc: 1.0000
# Epoch 20/20
# 691/691 [==============================] - 0s 123us/sample - loss: 0.0266 - acc: 1.0000
# Epoch 1/20
# 691/691 [==============================] - 0s 456us/sample - loss: 3.0035 - acc: 0.1693
# Epoch 2/20
# 691/691 [==============================] - 0s 120us/sample - loss: 2.0284 - acc: 0.4544
# Epoch 3/20
# 691/691 [==============================] - 0s 126us/sample - loss: 1.3387 - acc: 0.6324
# Epoch 4/20
# 691/691 [==============================] - 0s 130us/sample - loss: 0.9278 - acc: 0.7569
# Epoch 5/20
# 691/691 [==============================] - 0s 127us/sample - loss: 0.6896 - acc: 0.8480
# Epoch 6/20
# 691/691 [==============================] - 0s 115us/sample - loss: 0.4803 - acc: 0.9117
# Epoch 7/20
# 691/691 [==============================] - 0s 120us/sample - loss: 0.3918 - acc: 0.9074
# Epoch 8/20
# 691/691 [==============================] - 0s 121us/sample - loss: 0.3124 - acc: 0.9320
# Epoch 9/20
# 691/691 [==============================] - 0s 130us/sample - loss: 0.2445 - acc: 0.9595s - loss: 0.2566 - acc: 0.955
# Epoch 10/20
# 691/691 [==============================] - 0s 120us/sample - loss: 0.2144 - acc: 0.9653
# Epoch 11/20
# 691/691 [==============================] - 0s 123us/sample - loss: 0.1391 - acc: 0.9812
# Epoch 12/20
# 691/691 [==============================] - 0s 132us/sample - loss: 0.1002 - acc: 0.9986
# Epoch 13/20
# 691/691 [==============================] - 0s 122us/sample - loss: 0.0915 - acc: 0.9971
# Epoch 14/20
# 691/691 [==============================] - 0s 130us/sample - loss: 0.0708 - acc: 1.0000
# Epoch 15/20
# 691/691 [==============================] - 0s 123us/sample - loss: 0.0593 - acc: 1.0000
# Epoch 16/20
# 691/691 [==============================] - 0s 127us/sample - loss: 0.0529 - acc: 1.0000
# Epoch 17/20
# 691/691 [==============================] - 0s 127us/sample - loss: 0.0436 - acc: 1.0000
# Epoch 18/20
# 691/691 [==============================] - 0s 121us/sample - loss: 0.0370 - acc: 1.0000
# Epoch 19/20
# 691/691 [==============================] - 0s 120us/sample - loss: 0.0318 - acc: 1.0000
# Epoch 20/20
# 691/691 [==============================] - 0s 124us/sample - loss: 0.0276 - acc: 1.0000
# Epoch 1/20
# 518/518 [==============================] - 1s 2ms/sample - loss: 4.0779 - acc: 0.0811
# Epoch 2/20
# 518/518 [==============================] - 1s 1ms/sample - loss: 2.6029 - acc: 0.2664
# Epoch 3/20
# 518/518 [==============================] - 1s 1ms/sample - loss: 1.9141 - acc: 0.4595
# Epoch 4/20
# 518/518 [==============================] - 1s 1ms/sample - loss: 1.5395 - acc: 0.5367
# Epoch 5/20
# 518/518 [==============================] - 1s 2ms/sample - loss: 1.2383 - acc: 0.6274
# Epoch 6/20
# 518/518 [==============================] - 1s 2ms/sample - loss: 1.1088 - acc: 0.6660
# Epoch 7/20
# 518/518 [==============================] - 1s 1ms/sample - loss: 0.8848 - acc: 0.7239
# Epoch 8/20
# 518/518 [==============================] - 1s 1ms/sample - loss: 0.6870 - acc: 0.7973
# Epoch 9/20
# 518/518 [==============================] - 1s 2ms/sample - loss: 0.6825 - acc: 0.7780
# Epoch 10/20
# 518/518 [==============================] - 1s 1ms/sample - loss: 0.5887 - acc: 0.8147
# Epoch 11/20
# 518/518 [==============================] - 1s 1ms/sample - loss: 0.4882 - acc: 0.8764
# Epoch 12/20
# 518/518 [==============================] - 1s 1ms/sample - loss: 0.3797 - acc: 0.9247
# Epoch 13/20
# 518/518 [==============================] - 1s 1ms/sample - loss: 0.3730 - acc: 0.8919
# Epoch 14/20
# 518/518 [==============================] - 1s 1ms/sample - loss: 0.3214 - acc: 0.9151
# Epoch 15/20
# 518/518 [==============================] - 1s 1ms/sample - loss: 0.2397 - acc: 0.9363
# Epoch 16/20
# 518/518 [==============================] - 1s 2ms/sample - loss: 0.2009 - acc: 0.9556 0s - loss: 0.2208 - acc: 0.
# Epoch 17/20
# 518/518 [==============================] - 1s 1ms/sample - loss: 0.1619 - acc: 0.9826
# Epoch 18/20
# 518/518 [==============================] - 1s 1ms/sample - loss: 0.1772 - acc: 0.9633
# Epoch 19/20
# 518/518 [==============================] - 1s 1ms/sample - loss: 0.2105 - acc: 0.9421
# Epoch 20/20
# 518/518 [==============================] - 1s 1ms/sample - loss: 0.2346 - acc: 0.9382
# Epoch 1/20
# 518/518 [==============================] - 0s 618us/sample - loss: 3.0752 - acc: 0.1622
# Epoch 2/20
# 518/518 [==============================] - 0s 140us/sample - loss: 2.2421 - acc: 0.3880
# Epoch 3/20
# 518/518 [==============================] - 0s 133us/sample - loss: 1.5081 - acc: 0.6274
# Epoch 4/20
# 518/518 [==============================] - 0s 135us/sample - loss: 1.0545 - acc: 0.7066
# Epoch 5/20
# 518/518 [==============================] - 0s 135us/sample - loss: 0.7385 - acc: 0.8398
# Epoch 6/20
# 518/518 [==============================] - 0s 137us/sample - loss: 0.7049 - acc: 0.8108
# Epoch 7/20
# 518/518 [==============================] - 0s 137us/sample - loss: 0.4948 - acc: 0.8784
# Epoch 8/20
# 518/518 [==============================] - 0s 131us/sample - loss: 0.4222 - acc: 0.8822
# Epoch 9/20
# 518/518 [==============================] - 0s 145us/sample - loss: 0.3261 - acc: 0.9344
# Epoch 10/20
# 518/518 [==============================] - 0s 154us/sample - loss: 0.2320 - acc: 0.9749
# Epoch 11/20
# 518/518 [==============================] - 0s 133us/sample - loss: 0.1941 - acc: 0.9730
# Epoch 12/20
# 518/518 [==============================] - 0s 133us/sample - loss: 0.1591 - acc: 0.9826
# Epoch 13/20
# 518/518 [==============================] - 0s 137us/sample - loss: 0.1173 - acc: 0.9903
# Epoch 14/20
# 518/518 [==============================] - 0s 135us/sample - loss: 0.0984 - acc: 0.9942
# Epoch 15/20
# 518/518 [==============================] - 0s 135us/sample - loss: 0.0848 - acc: 0.9961
# Epoch 16/20
# 518/518 [==============================] - 0s 139us/sample - loss: 0.0727 - acc: 1.0000
# Epoch 17/20
# 518/518 [==============================] - 0s 135us/sample - loss: 0.0666 - acc: 0.9981
# Epoch 18/20
# 518/518 [==============================] - 0s 131us/sample - loss: 0.0555 - acc: 1.0000
# Epoch 19/20
# 518/518 [==============================] - 0s 143us/sample - loss: 0.0531 - acc: 1.0000
# Epoch 20/20
# 518/518 [==============================] - 0s 131us/sample - loss: 0.0418 - acc: 1.0000
# Epoch 1/20
# 518/518 [==============================] - 0s 678us/sample - loss: 3.1124 - acc: 0.1351
# Epoch 2/20
# 518/518 [==============================] - 0s 177us/sample - loss: 2.2435 - acc: 0.4228
# Epoch 3/20
# 518/518 [==============================] - 0s 152us/sample - loss: 1.5650 - acc: 0.5965
# Epoch 4/20
# 518/518 [==============================] - 0s 139us/sample - loss: 1.1414 - acc: 0.6969
# Epoch 5/20
# 518/518 [==============================] - 0s 127us/sample - loss: 0.8307 - acc: 0.7857
# Epoch 6/20
# 518/518 [==============================] - 0s 140us/sample - loss: 0.6805 - acc: 0.8282
# Epoch 7/20
# 518/518 [==============================] - 0s 148us/sample - loss: 0.5613 - acc: 0.8552
# Epoch 8/20
# 518/518 [==============================] - 0s 139us/sample - loss: 0.4673 - acc: 0.8784
# Epoch 9/20
# 518/518 [==============================] - 0s 144us/sample - loss: 0.3877 - acc: 0.8900
# Epoch 10/20
# 518/518 [==============================] - 0s 144us/sample - loss: 0.2836 - acc: 0.9479
# Epoch 11/20
# 518/518 [==============================] - 0s 141us/sample - loss: 0.2078 - acc: 0.9710
# Epoch 12/20
# 518/518 [==============================] - 0s 154us/sample - loss: 0.1763 - acc: 0.9826
# Epoch 13/20
# 518/518 [==============================] - 0s 160us/sample - loss: 0.1447 - acc: 0.9846
# Epoch 14/20
# 518/518 [==============================] - 0s 144us/sample - loss: 0.1220 - acc: 0.9981
# Epoch 15/20
# 518/518 [==============================] - 0s 141us/sample - loss: 0.1043 - acc: 0.9923
# Epoch 16/20
# 518/518 [==============================] - 0s 154us/sample - loss: 0.0920 - acc: 0.9923
# Epoch 17/20
# 518/518 [==============================] - 0s 144us/sample - loss: 0.0713 - acc: 1.0000
# Epoch 18/20
# 518/518 [==============================] - 0s 154us/sample - loss: 0.0544 - acc: 1.0000
# Epoch 19/20
# 518/518 [==============================] - 0s 146us/sample - loss: 0.0450 - acc: 1.0000
# Epoch 20/20
# 518/518 [==============================] - 0s 150us/sample - loss: 0.0430 - acc: 1.0000
# Epoch 1/20
# 345/345 [==============================] - 1s 2ms/sample - loss: 4.6614 - acc: 0.0406
# Epoch 2/20
# 345/345 [==============================] - 1s 1ms/sample - loss: 3.1051 - acc: 0.1449
# Epoch 3/20
# 345/345 [==============================] - 1s 1ms/sample - loss: 2.4085 - acc: 0.3159
# Epoch 4/20
# 345/345 [==============================] - 1s 1ms/sample - loss: 2.0267 - acc: 0.4406
# Epoch 5/20
# 345/345 [==============================] - 1s 2ms/sample - loss: 1.6689 - acc: 0.5333
# Epoch 6/20
# 345/345 [==============================] - 1s 1ms/sample - loss: 1.4067 - acc: 0.6261
# Epoch 7/20
# 345/345 [==============================] - 1s 1ms/sample - loss: 1.2545 - acc: 0.6290
# Epoch 8/20
# 345/345 [==============================] - 1s 1ms/sample - loss: 1.0843 - acc: 0.6870
# Epoch 9/20
# 345/345 [==============================] - 1s 1ms/sample - loss: 0.8548 - acc: 0.7478
# Epoch 10/20
# 345/345 [==============================] - 1s 1ms/sample - loss: 0.7309 - acc: 0.8029
# Epoch 11/20
# 345/345 [==============================] - 1s 1ms/sample - loss: 0.6368 - acc: 0.8435
# Epoch 12/20
# 345/345 [==============================] - 1s 1ms/sample - loss: 0.5527 - acc: 0.8609
# Epoch 13/20
# 345/345 [==============================] - 1s 1ms/sample - loss: 0.5270 - acc: 0.8580
# Epoch 14/20
# 345/345 [==============================] - 1s 1ms/sample - loss: 0.4887 - acc: 0.8464
# Epoch 15/20
# 345/345 [==============================] - 1s 2ms/sample - loss: 0.3982 - acc: 0.9130
# Epoch 16/20
# 345/345 [==============================] - 1s 1ms/sample - loss: 0.3576 - acc: 0.9130
# Epoch 17/20
# 345/345 [==============================] - 1s 2ms/sample - loss: 0.3396 - acc: 0.9246
# Epoch 18/20
# 345/345 [==============================] - 1s 1ms/sample - loss: 0.2672 - acc: 0.9623
# Epoch 19/20
# 345/345 [==============================] - 1s 1ms/sample - loss: 0.2405 - acc: 0.9536
# Epoch 20/20
# 345/345 [==============================] - 1s 2ms/sample - loss: 0.1826 - acc: 0.9797
# Epoch 1/20
# 345/345 [==============================] - 0s 954us/sample - loss: 3.2035 - acc: 0.0957
# Epoch 2/20
# 345/345 [==============================] - 0s 136us/sample - loss: 2.5643 - acc: 0.2841
# Epoch 3/20
# 345/345 [==============================] - 0s 147us/sample - loss: 1.9972 - acc: 0.5188
# Epoch 4/20
# 345/345 [==============================] - 0s 139us/sample - loss: 1.5615 - acc: 0.5971
# Epoch 5/20
# 345/345 [==============================] - 0s 144us/sample - loss: 1.1403 - acc: 0.7565
# Epoch 6/20
# 345/345 [==============================] - 0s 156us/sample - loss: 0.8908 - acc: 0.8522
# Epoch 7/20
# 345/345 [==============================] - 0s 144us/sample - loss: 0.6764 - acc: 0.8696
# Epoch 8/20
# 345/345 [==============================] - 0s 147us/sample - loss: 0.5251 - acc: 0.8812
# Epoch 9/20
# 345/345 [==============================] - 0s 145us/sample - loss: 0.4706 - acc: 0.9130
# Epoch 10/20
# 345/345 [==============================] - 0s 156us/sample - loss: 0.3656 - acc: 0.9391
# Epoch 11/20
# 345/345 [==============================] - 0s 152us/sample - loss: 0.2898 - acc: 0.9652
# Epoch 12/20
# 345/345 [==============================] - 0s 147us/sample - loss: 0.2473 - acc: 0.9652
# Epoch 13/20
# 345/345 [==============================] - 0s 147us/sample - loss: 0.1814 - acc: 0.9913
# Epoch 14/20
# 345/345 [==============================] - 0s 142us/sample - loss: 0.1552 - acc: 0.9942
# Epoch 15/20
# 345/345 [==============================] - 0s 145us/sample - loss: 0.1266 - acc: 0.9913
# Epoch 16/20
# 345/345 [==============================] - 0s 150us/sample - loss: 0.1056 - acc: 1.0000
# Epoch 17/20
# 345/345 [==============================] - 0s 147us/sample - loss: 0.0883 - acc: 1.0000
# Epoch 18/20
# 345/345 [==============================] - 0s 145us/sample - loss: 0.0772 - acc: 1.0000
# Epoch 19/20
# 345/345 [==============================] - 0s 144us/sample - loss: 0.0685 - acc: 1.0000
# Epoch 20/20
# 345/345 [==============================] - 0s 150us/sample - loss: 0.0574 - acc: 1.0000
# Epoch 1/20
# 345/345 [==============================] - 0s 953us/sample - loss: 3.2358 - acc: 0.0899
# Epoch 2/20
# 345/345 [==============================] - 0s 127us/sample - loss: 2.6585 - acc: 0.3101
# Epoch 3/20
# 345/345 [==============================] - 0s 133us/sample - loss: 2.0607 - acc: 0.5014
# Epoch 4/20
# 345/345 [==============================] - 0s 127us/sample - loss: 1.5440 - acc: 0.6464
# Epoch 5/20
# 345/345 [==============================] - 0s 136us/sample - loss: 1.1362 - acc: 0.7797
# Epoch 6/20
# 345/345 [==============================] - 0s 138us/sample - loss: 0.9221 - acc: 0.7942
# Epoch 7/20
# 345/345 [==============================] - 0s 136us/sample - loss: 0.7318 - acc: 0.8290
# Epoch 8/20
# 345/345 [==============================] - 0s 130us/sample - loss: 0.5238 - acc: 0.9130
# Epoch 9/20
# 345/345 [==============================] - 0s 139us/sample - loss: 0.4138 - acc: 0.9391
# Epoch 10/20
# 345/345 [==============================] - 0s 133us/sample - loss: 0.3131 - acc: 0.9652
# Epoch 11/20
# 345/345 [==============================] - 0s 136us/sample - loss: 0.2606 - acc: 0.9710
# Epoch 12/20
# 345/345 [==============================] - 0s 139us/sample - loss: 0.2083 - acc: 0.9797
# Epoch 13/20
# 345/345 [==============================] - 0s 133us/sample - loss: 0.1950 - acc: 0.9884
# Epoch 14/20
# 345/345 [==============================] - 0s 136us/sample - loss: 0.1311 - acc: 0.9971
# Epoch 15/20
# 345/345 [==============================] - 0s 135us/sample - loss: 0.1057 - acc: 0.9942
# Epoch 16/20
# 345/345 [==============================] - 0s 133us/sample - loss: 0.0872 - acc: 1.0000
# Epoch 17/20
# 345/345 [==============================] - 0s 121us/sample - loss: 0.0735 - acc: 1.0000
# Epoch 18/20
# 345/345 [==============================] - 0s 144us/sample - loss: 0.0645 - acc: 1.0000
# Epoch 19/20
# 345/345 [==============================] - 0s 130us/sample - loss: 0.0623 - acc: 0.9971
# Epoch 20/20
# 345/345 [==============================] - 0s 127us/sample - loss: 0.0560 - acc: 1.0000
# Epoch 1/20
# 172/172 [==============================] - 1s 3ms/sample - loss: 4.9438 - acc: 0.0465
# Epoch 2/20
# 172/172 [==============================] - 0s 2ms/sample - loss: 3.8117 - acc: 0.0930
# Epoch 3/20
# 172/172 [==============================] - 0s 2ms/sample - loss: 3.1123 - acc: 0.2035
# Epoch 4/20
# 172/172 [==============================] - 0s 2ms/sample - loss: 2.6738 - acc: 0.2326
# Epoch 5/20
# 172/172 [==============================] - 0s 2ms/sample - loss: 2.3563 - acc: 0.3488
# Epoch 6/20
# 172/172 [==============================] - 0s 2ms/sample - loss: 2.0125 - acc: 0.3953
# Epoch 7/20
# 172/172 [==============================] - 0s 2ms/sample - loss: 1.6961 - acc: 0.5407
# Epoch 8/20
# 172/172 [==============================] - 0s 2ms/sample - loss: 1.5587 - acc: 0.5640
# Epoch 9/20
# 172/172 [==============================] - 0s 2ms/sample - loss: 1.2770 - acc: 0.6744
# Epoch 10/20
# 172/172 [==============================] - 0s 2ms/sample - loss: 1.1050 - acc: 0.7558
# Epoch 11/20
# 172/172 [==============================] - 0s 2ms/sample - loss: 0.9465 - acc: 0.7849
# Epoch 12/20
# 172/172 [==============================] - 0s 2ms/sample - loss: 0.8397 - acc: 0.7849
# Epoch 13/20
# 172/172 [==============================] - 0s 2ms/sample - loss: 0.7371 - acc: 0.8081
# Epoch 14/20
# 172/172 [==============================] - 0s 2ms/sample - loss: 0.6725 - acc: 0.8023
# Epoch 15/20
# 172/172 [==============================] - 0s 2ms/sample - loss: 0.6020 - acc: 0.8314
# Epoch 16/20
# 172/172 [==============================] - 0s 2ms/sample - loss: 0.4990 - acc: 0.9070
# Epoch 17/20
# 172/172 [==============================] - 0s 2ms/sample - loss: 0.4590 - acc: 0.9012
# Epoch 18/20
# 172/172 [==============================] - 0s 2ms/sample - loss: 0.3815 - acc: 0.9360
# Epoch 19/20
# 172/172 [==============================] - 0s 2ms/sample - loss: 0.3727 - acc: 0.9302
# Epoch 20/20
# 172/172 [==============================] - 0s 2ms/sample - loss: 0.2965 - acc: 0.9651
# Epoch 1/20
# 172/172 [==============================] - 0s 2ms/sample - loss: 3.3639 - acc: 0.0291
# Epoch 2/20
# 172/172 [==============================] - 0s 162us/sample - loss: 2.9447 - acc: 0.2209
# Epoch 3/20
# 172/172 [==============================] - 0s 162us/sample - loss: 2.6021 - acc: 0.3953
# Epoch 4/20
# 172/172 [==============================] - 0s 168us/sample - loss: 2.2323 - acc: 0.5465
# Epoch 5/20
# 172/172 [==============================] - 0s 168us/sample - loss: 1.8567 - acc: 0.6221
# Epoch 6/20
# 172/172 [==============================] - 0s 151us/sample - loss: 1.5272 - acc: 0.6977
# Epoch 7/20
# 172/172 [==============================] - 0s 162us/sample - loss: 1.2346 - acc: 0.8372
# Epoch 8/20
# 172/172 [==============================] - 0s 168us/sample - loss: 0.9584 - acc: 0.8488
# Epoch 9/20
# 172/172 [==============================] - 0s 157us/sample - loss: 0.7468 - acc: 0.9128
# Epoch 10/20
# 172/172 [==============================] - 0s 163us/sample - loss: 0.5752 - acc: 0.9419
# Epoch 11/20
# 172/172 [==============================] - 0s 168us/sample - loss: 0.4768 - acc: 0.9593
# Epoch 12/20
# 172/172 [==============================] - 0s 166us/sample - loss: 0.3868 - acc: 0.9535
# Epoch 13/20
# 172/172 [==============================] - 0s 168us/sample - loss: 0.3141 - acc: 0.9593
# Epoch 14/20
# 172/172 [==============================] - 0s 163us/sample - loss: 0.2450 - acc: 0.9767
# Epoch 15/20
# 172/172 [==============================] - 0s 160us/sample - loss: 0.1958 - acc: 0.9942
# Epoch 16/20
# 172/172 [==============================] - 0s 163us/sample - loss: 0.1651 - acc: 0.9942
# Epoch 17/20
# 172/172 [==============================] - 0s 168us/sample - loss: 0.1336 - acc: 1.0000
# Epoch 18/20
# 172/172 [==============================] - 0s 156us/sample - loss: 0.1186 - acc: 1.0000
# Epoch 19/20
# 172/172 [==============================] - 0s 162us/sample - loss: 0.1015 - acc: 1.0000
# Epoch 20/20
# 172/172 [==============================] - 0s 162us/sample - loss: 0.0887 - acc: 1.0000
# Epoch 1/20
# 172/172 [==============================] - 0s 2ms/sample - loss: 3.3844 - acc: 0.0291
# Epoch 2/20
# 172/172 [==============================] - 0s 145us/sample - loss: 2.9769 - acc: 0.1977
# Epoch 3/20
# 172/172 [==============================] - 0s 162us/sample - loss: 2.5141 - acc: 0.4186
# Epoch 4/20
# 172/172 [==============================] - 0s 163us/sample - loss: 2.1094 - acc: 0.5291
# Epoch 5/20
# 172/172 [==============================] - 0s 157us/sample - loss: 1.6264 - acc: 0.7442
# Epoch 6/20
# 172/172 [==============================] - 0s 167us/sample - loss: 1.2444 - acc: 0.8779
# Epoch 7/20
# 172/172 [==============================] - 0s 156us/sample - loss: 0.9232 - acc: 0.9070
# Epoch 8/20
# 172/172 [==============================] - 0s 168us/sample - loss: 0.7330 - acc: 0.9070
# Epoch 9/20
# 172/172 [==============================] - 0s 186us/sample - loss: 0.5678 - acc: 0.9477
# Epoch 10/20
# 172/172 [==============================] - 0s 168us/sample - loss: 0.4177 - acc: 0.9651
# Epoch 11/20
# 172/172 [==============================] - 0s 162us/sample - loss: 0.3309 - acc: 0.9826
# Epoch 12/20
# 172/172 [==============================] - 0s 160us/sample - loss: 0.2650 - acc: 0.9826
# Epoch 13/20
# 172/172 [==============================] - 0s 169us/sample - loss: 0.2174 - acc: 0.9884
# Epoch 14/20
# 172/172 [==============================] - 0s 157us/sample - loss: 0.1689 - acc: 1.0000
# Epoch 15/20
# 172/172 [==============================] - 0s 162us/sample - loss: 0.1398 - acc: 0.9942
# Epoch 16/20
# 172/172 [==============================] - 0s 158us/sample - loss: 0.1126 - acc: 1.0000
# Epoch 17/20
# 172/172 [==============================] - 0s 168us/sample - loss: 0.0963 - acc: 1.0000
# Epoch 18/20
# 172/172 [==============================] - 0s 157us/sample - loss: 0.0799 - acc: 1.0000
# Epoch 19/20
# 172/172 [==============================] - 0s 157us/sample - loss: 0.0743 - acc: 1.0000
# Epoch 20/20
# 172/172 [==============================] - 0s 157us/sample - loss: 0.0621 - acc: 1.0000

# %%
print(accmat)
# Out:
# [[0.87283237 0.84393064 0.83815029 0.86705202]
#  [0.74855491 0.84971098 0.87283237 0.89306358]
#  [0.71868979 0.80154143 0.81310212 0.86897881]
#  [0.48121387 0.69942197 0.69364162 0.73554913]]

# %%
print(recmat)
# Out:
# [[0.87654321 0.84567901 0.83950617 0.8686067 ]
#  [0.7485755  0.84947768 0.87250712 0.89292498]
#  [0.71900585 0.80243665 0.81374269 0.86959064]
#  [0.48233618 0.7        0.69356125 0.73584046]]

# %%
print(premat)
# Out:
# [[0.89748677 0.86719577 0.86446208 0.88836781]
#  [0.82077355 0.85369178 0.8761746  0.89736985]
#  [0.75141582 0.82138285 0.83929603 0.87389204]
#  [0.51659363 0.70898368 0.695284   0.75348241]]

# %%
accdf = pd.DataFrame(accmat,columns=['Depth','Skeleton','Sensor','Fusion'],index=['0.2','0.4','0.6','0.8'])
accdf
# Out:
#         Depth  Skeleton    Sensor    Fusion
# 0.2  0.872832  0.843931  0.838150  0.867052
# 0.4  0.748555  0.849711  0.872832  0.893064
# 0.6  0.718690  0.801541  0.813102  0.868979
# 0.8  0.481214  0.699422  0.693642  0.735549

# %%
accdf = pd.DataFrame(accmat,columns=['Depth','Skeleton','Sensor','Fusion'],index=['0.2','0.4','0.6','0.8'])
accdf.plot(kind='bar',figsize=(15,8))
plt.xlabel('Training Data Size',fontsize=15)
plt.ylabel('Accuracy',fontsize=15)
plt.title('Accuracy Comparison',fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Accuracy Comparison')

# %%
predf = pd.DataFrame(premat,columns=['Depth','Skeleton','Sensor','Fusion'],index=['0.2','0.4','0.6','0.8'])
predf.plot(kind='bar',figsize=(15,8))
plt.xlabel('Training Data Size',fontsize=15)
plt.ylabel('Precision',fontsize=15)
plt.title('Precision Comparison',fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Precision Comparison')

# %%
recdf = pd.DataFrame(recmat,columns=['Depth','Skeleton','Sensor','Fusion'],index=['0.2','0.4','0.6','0.8'])
recdf.plot(kind='bar',figsize=(15,8))
plt.xlabel('Training Data Size',fontsize=15)
plt.ylabel('Recall',fontsize=15)
plt.title('Recall Comparison',fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Recall Comparison')
